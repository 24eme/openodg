# %%
import pandas as pd
drev = pd.read_csv("../../web/exports/drev.csv", encoding="iso8859_15", delimiter=";", decimal=",",dtype={'CVI Opérateur': 'str', 'Identifiant': 'str','Appellation': 'str','Campagne': 'str'}, low_memory=False)

drev = drev[['Campagne','Produit','Nom Opérateur','Adresse Opérateur','Code postal Opérateur','Commune Opérateur','CVI Opérateur','Siret Opérateur','VCI Stock précédent','Superficie revendiqué','Volume revendiqué issu du mutage','Volume revendiqué issu du vci','VCI Complément','VCI Substitution','VCI Rafraichi','VCI Destruction','Volume revendiqué issu de la récolte','VCI Stock final']]

# %%
drev_2020 = drev[drev['Campagne'] == '2020'].fillna(0)
drev_2020['has_stock'] = drev_2020['VCI Stock précédent'] + drev_2020['VCI Stock final']
drev_2020['VCI N-1 revendiqué'] = drev_2020['Volume revendiqué issu du vci'] + drev_2020['VCI Destruction']
drev_2020 = drev_2020[drev_2020['has_stock'] > 0]
#drev_2020 = drev_2020.sort_values(['Produit'])  
drev_2020 = drev_2020.rename(columns={'VCI Stock précédent': 'VCI N-1','Superficie revendiqué':'Surface (L4)','Volume revendiqué issu du mutage': 'Vol AOC (L15)','Volume revendiqué issu du vci':'Vol VCI (L19)', 'VCI Complément': 'Complément','VCI Substitution':'Substitution','VCI Rafraichi':'Rafraichissement','VCI Destruction':'Destruction','Volume revendiqué issu de la récolte':'Vol AOC issu de la récolte'}) 
drev_2020 = drev_2020.drop(['has_stock', 'Campagne','VCI Stock final'],axis=1) 
drev_2020.loc['Total'] = drev_2020[['Complément','VCI N-1','Rafraichissement','Destruction','VCI N-1 revendiqué']].sum()
drev_2020.reset_index().to_csv("../../web/exports/inao_vci_drev_2020.csv", encoding="iso8859_15", sep=";", index=False, decimal=",")
# Out:
#                                           Produit  \
# 13334  Côtes du Rhône Villages Saint-Andéol Rouge
# 13335                        Côtes du Rhône Rouge
# 13390                        Côtes du Rhône Rouge
# 13413                        Côtes du Rhône Rouge
# 13415               Côtes du Rhône Villages Rouge
# ...                                           ...
# 16416                     Beaumes de Venise Rouge
# 16429  Côtes du Rhône Villages Plan de Dieu Rouge
# 16467                              Cairanne Rouge
# 16670                        Côtes du Rhône Rouge
# Total                                         NaN
#
#                                         Nom Opérateur  \
# 13334                                 DORTHE JEAN-LUC
# 13335                                  ROMAN PHILIPPE
# 13390                          CHATEAU D'ORSAN (SCEA)
# 13413                DOMAINE DU BOIS DES DAMES (SCEA)
# 13415                DOMAINE DU BOIS DES DAMES (SCEA)
# ...                                               ...
# 16416                                    RHONEA (SCA)
# 16429                                   AUBERT DAMIEN
# 16467                            ALAIN BOISSON (SCEA)
# 16670  CAVE DES VIGNERONS DE BOURG SAINT ANDEOL (SCA)
# Total                                             NaN
#
#                                Adresse Opérateur  Code postal Opérateur  \
# 13334  Domaine de Couron-1677 Chemin de Labégude                 7700.0
# 13335                                    LE PLAN                 7700.0
# 13390                         3 PLACE DU CHÂTEAU                30200.0
# 13413                         DME BOIS DES DAMES                84150.0
# 13415                         DME BOIS DES DAMES                84150.0
# ...                                          ...                    ...
# 16416                    228 ROUTE DE CARPENTRAS                84190.0
# 16429                            LE GRAND RETOUR                84850.0
# 16467                       285 CHEMIN DU MOULIN                84290.0
# 16670                         RUE MARIUS VINCENT                 7700.0
# Total                                        NaN                    NaN
#
#           Commune Opérateur CVI Opérateur  Siret Opérateur   VCI N-1  \
# 13334   ST MARCEL D ARDECHE    0725902420     3.326057e+13      5.00
# 13335  ST MARTIN D ARDECHE     0726801000     3.899608e+13    220.00
# 13390                ORSAN     3019100130     3.206861e+13    335.00
# 13413                VIOLES    8414901520     7.832612e+13    129.00
# 13415                VIOLES    8414901520     7.832612e+13    600.00
# ...                     ...           ...              ...       ...
# 16416    BEAUMES DE VENISE     8401200151     8.076726e+13    209.98
# 16429           TRAVAILLAN     8413400081     8.311852e+13      0.00
# 16467              CAIRANNE    8402800151     8.341820e+13      0.00
# 16670       BOURG ST ANDEOL    0704200051     8.805882e+13    577.76
# Total                   NaN           NaN              NaN  52386.13
#
#        Surface (L4)  Vol AOC (L15)  Vol VCI (L19)  Complément  Substitution  \
# 13334        1.3541            0.0           5.00        5.00           0.0
# 13335       18.3580            0.0         220.00      220.00           0.0
# 13390       46.3175            0.0         335.00      335.00           0.0
# 13413       40.2183            0.0         129.00        0.00           0.0
# 13415      110.0000            0.0         600.00        0.00           0.0
# ...             ...            ...            ...         ...           ...
# 16416      313.2850            0.0         209.21       16.62           0.0
# 16429        8.0000            0.0           0.00        0.00           0.0
# 16467        2.3605            0.0           0.00        0.00           0.0
# 16670      126.6636            0.0         577.76        8.00           0.0
# Total           NaN            NaN            NaN    14975.30           NaN
#
#        Rafraichissement  Destruction  Vol AOC issu de la récolte  \
# 13334              0.00         0.00                       47.00
# 13335              0.00         0.00                      674.00
# 13390              0.00         0.00                     1253.00
# 13413            129.00         0.00                     1922.00
# 13415            600.00         0.00                     4240.00
# ...                 ...          ...                         ...
# 16416            192.59         0.77                    10826.75
# 16429              0.00         0.00                      328.00
# 16467              0.00         0.00                       89.70
# 16670            569.76         0.00                     5152.29
# Total          36844.13       566.70                         NaN
#
#        VCI N-1 revendiqué
# 13334                5.00
# 13335              220.00
# 13390              335.00
# 13413              129.00
# 13415              600.00
# ...                   ...
# 16416              209.98
# 16429                0.00
# 16467                0.00
# 16670              577.76
# Total            52386.13
#
# [127 rows x 17 columns]
